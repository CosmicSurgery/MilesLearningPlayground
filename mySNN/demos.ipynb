# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import networkx as nx

# my packages
from SNNnetwork import Network
from SNNcortex import Cortex
from SNNneuron import regularSpiking, fastSpiking, lowThresholdSpiking, intrinsicBurst, dummyNode, Neuron, neuron_radius
from SNNsynapse import Synapse
from SNNvisual import visual as v

# %matplotlib notebook

# %%
'''
network
create a 

'''
test_net = Network()
test_layer = Cortex(test_net, n = 20, layer=True, tuning_type = 'square root')

T1, T2, h=0, 100, 0.1
clk = np.arange(T1,T2,h)
counter = 0
for t in clk:
    counter +=0.1
    for n in test_net.neurons:
        n.step(t)
# Out:
# 0

# %%
for n in test_net.neurons:
    print(n.iMemory[-1])
# Out:
# 0
# 0
# 3.1622776601683795
# 3.1622776601683795
# 3.1622776601683795
# 3.1622776601683795
# 0
# 0
# 0
# 0
# 3.1622776601683795
# 3.1622776601683795
# 3.1622776601683795
# 0
# 3.1622776601683795
# 0
# 3.1622776601683795
# 3.1622776601683795
# 3.1622776601683795
# 0

# %%
print(test_net.neurons[-1].spikes)
print(test_net.neurons[-1].t)
len(test_net.neurons[-1].spikes) / np.ceil(test_net.neurons[-1].t)
# Out:
# []
# 99.9999999999986
# 0.0

# %%
v.debug(test_net, scheme='frequency')
v.showRaster(test_net)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
net = Network()
P = Cortex(net,n=20, layer = True)
S = Cortex(net)
M = Cortex(net)

net.connectCortices(P,S)
net.connectCortices(S,M)


T1, T2, h=0, 100, 0.1
clk = np.arange(T1,T2,h)

for t in clk:
    for n in net.neurons:
        n.step(t)
    for s in net.synapses:  
        s.step(t)



v.showNetwork(net, scheme = 'frequency', labels_on = True)
v.showRaster(net)
# Out:
# 16
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-d3eab50dc67d> in <module>
#       4 M = Cortex(net)
#       5
# ----> 6 net.connectCortices(P,S)
#       7 net.connectCortices(S,M)
#       8
#
# ~/fetzlab/fetzlab-JichySNN/mySNN/SNNnetwork.py in connectCortices(self, cortex_one, cortex_two, random_select, num_connections)
#      39         print(len(self.getOutputNeurons(cortex_one, random_select = random_select, num_connections = num_connections)))
#      40         for i in range(num_connections):
# ---> 41             self.__formConnections(self.getOutputNeurons(cortex_one, random_select = random_select, num_connections = num_connections)[i],self.getInputNeurons(cortex_two, random_select = random_select, num_connections=num_connections)[i])
#      42
#      43     def get_neurons_from(self,cortex):
#
# IndexError: list index out of range

# %% [markdown]
# one in one out

# %%
T1, T2, h = 0, 100, 0.1
clk = np.arange(T1, T2, h)  
in1 = dummyNode()
out1 = regularSpiking()
s = Synapse(in1, out1)

for t in clk:
    in1.step(t)
    out1.step(t)
    s.step(t)

plt.figure()
plt.plot(clk,in1.iMemory,label = 'offset=6')
plt.plot(clk,in1.vMemory,label='neuron1')
plt.plot(clk,s.net_memory,label='postsynaptic potential')
plt.plot(clk,out1.vMemory,label='neuron2')
plt.legend()
plt.show()
# Out:
# <div id='8d4b0977-ae89-42cc-857a-fb11b20fed17'></div>

# %%
net = Network()
S = Cortex(net)
P = Cortex(net,n=20, layer = True)
S = Cortex(net)
M = Cortex(net)
# Out:
# 0
# 1
# 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import networkx as nx

# my packages
from SNNnetwork import Network
from SNNcortex import Cortex
from SNNneuron import regularSpiking, fastSpiking, lowThresholdSpiking, intrinsicBurst, dummyNode, Neuron, neuron_radius
from SNNsynapse import Synapse
from SNNvisual import visual as v

# %matplotlib notebook

# %%
net = Network()
S = Cortex(net)
# Out:
# 0

# %%
len(S.neurons)
# Out:
# 246

# %%
plt.hist([ k.is_an_input + k.is_an_output for k in S.neurons])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
len(S.neurons)
# Out:
# 100

# %%
v.showNetwork(net)
# Out:
# <img src="data:image/png;base64,..." width="640">
